# %% [markdown]
# <a href="https://colab.research.google.com/github/PrishaAggarwal/Conversational_AI_All_cources/blob/main/Accelerated_Data_Science/Lab/My_files_Colab/Convo_AI_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Selenium used for data collection and for software testing
#Selenium used for dynamic websites
#dynamic pages means jaha hamare input se acc pages vary and jaha websites mein js jiyda hoti hai

#combination of bs4 and selenium is best
#jo cheeze static chahiye use bs4
#jo dynamix cheeze handle krni use selenium

#ismein we need browser ke drivers because selenium uses browsers
#browser opened in python web driver
#help mein about mein jake see browser ka version

#same version file donwload kro
#zip file mein se extract .exe file from there

#try to use edge since chrome ka latest driver is not available
