# %% [markdown]
# We discussed about corpus and its types <br>
# Python  has alot of in built corpus and we usually use our corpus <br>
# nltk : natural language tool kit..it has all ML and rule based natural language wali cheeze but we need deep learning  <br>
# We use it for pre processing of data and not for learning anything from natural language

# %%
# !pip install nltk
import nltk
# Out:
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 166.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
# ...

# %%
#if u want to use anything from nltk then u have to first download it and then import it
#lexical resourse is any collection of document that is no used in some learning process but used for understanding that language
#wordnet is  dictionary and oske semantics...like oske synonymns anonyms or alag alag jagah oska kya matlab kya hoga....iske parents kya hai child kya hia...tells whole relationship 
#stock words are high frequency words like ans the vagah jinka khud ka no meaning but gives semantic meaning to sentences...this is one lexical resources
#we have to download these lexical resources

#nltk.download()

#after running, ek puri collection open ho jayegi
#ek do package u wanna install then single quotes mein write inside brackets
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\prish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:632, in TraitType.get(self, obj, cls)
#     631 try:
# --> 632     value = obj._trait_values[self.name]
#     633 except KeyError:
#     634     # Check for a dynamic initializer.
#
# KeyError: 'type_printers'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:709, in PlainTextFormatter.__call__(self, obj)
#     703 else:
#     704     stream = StringIO()
#     705     printer = pretty.RepresentationPrinter(stream, self.verbose,
# ...

# %%
#after downloading u have to import it
from nltk.corpus import gutenberg,stopwords

# %% [markdown]
# Every corpus has 4 methods supported
# 1. .fileids : it will list the names of files present in corpus
# 2. raw : all data read character by charcater and osko read krega...for it there is nothing words or sentences..iske input mein we can fileid ki ek file ke dekhne hai ya phir list of files can also input
# 3. .words : list of words bta dega...same for its input as .raw
# 4. .sentences

# %% [markdown]
# .categories can be applicable to categorical corpus like brown(u can download brown corpus)
# brown.fileids(categories=['adventure']) #all files under adventure catgeory ...implement it
# brown.raw(fileid='cn29') #ismein sab aayega in raw form from cn29 file from adventure category

# %%
gutenberg.fileids()
#returning a list toh ispar sab list wale methods lagenge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:632, in TraitType.get(self, obj, cls)
#     631 try:
# --> 632     value = obj._trait_values[self.name]
#     633 except KeyError:
#     634     # Check for a dynamic initializer.
#
# KeyError: 'type_printers'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:709, in PlainTextFormatter.__call__(self, obj)
#     703 else:
#     704     stream = StringIO()
#     705     printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706         self.max_width, self.newline,
#     707         max_seq_length=self.max_seq_length,
#     708         singleton_pprinters=self.singleton_printers,
# ...

# %% [markdown]
# Now yeh sab corpus are outdates and we have to work on our dataset and on them
# we have to load our textual data into python
# read_csv file reads single file and not a corpus since its a collection of files
# so 2 methods
# 1. file objects
# import os #isse sabhi folder ke contents can be read
# filenames1 = os.listdir(path) #list directory....it will read all files in that directory/subdirectory on that path
# filesnames1 #to see names
# corpus =[]
# for i in filenames1 :
#     open(path+i,'r') #open creates a file object on the path we give and this caqn be used in diff modes like read,write,readwrite
#     #path+i ith path we are appending in that...toh os path par jke ith file ban jayegi
#    #f.read() #read file (f.read()) or read line by line or read lines
#    corpus1.append(f.read())
#    f.close()
# 3. plain text corpus reader
# from nltk.corpus import PlaintextCorpusReader  #it can read corpus from any path
# path = ' '
# a=PlaintextCorpusReaderorpusReader(path,'.*') #.* means all types of files will be read...vase u can give type of file like .txt vagah read kr skate ho
# now a(a is name of corpus we read) ka inbuilt corpus ban gya i.e jo methods inbuilt corpus par applicable hia voh ispar bhi lagenge aab
# after reading corpus u can store it in list or datafram whatever u want
# now ques is suppose corpus mein se sab documents ko list mein lekr aana hai how ?
# corpus = []
# filenames = a.fileids()
# for i in filenames:
#     #a.raw(i) raw content uthaye corresponding to that ith file
#    corpus.append(a.raw(i))
#
#    once list is created u can convert it into dataframe using pandas
# corpus_df = pd.dataframe(corpus,columns = ['docs']) #since single column hai toh single name dedo
